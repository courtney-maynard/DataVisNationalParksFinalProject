# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import folium
import seaborn as sns
import json
import plotly.express as px
from ast import literal_eval

# %%
tTrailsPossibly = pd.read_csv('AllTrailsCleanedData.csv')

tTrailsPossibly['Trail'] = tTrailsPossibly['trail_name']
tTrailsPossibly['Park_Name'] = tTrailsPossibly['national_park']
tTrailsPossibly['State'] = tTrailsPossibly['state_name']
tTrailsPossibly['Trail_Lat'] = tTrailsPossibly['lat']
tTrailsPossibly['Trail_Lng'] = tTrailsPossibly['lng']
tTrailsPossibly['Trail_Popularity'] = tTrailsPossibly['popularity']
tTrailsPossibly['Trail_Length'] = tTrailsPossibly['length_miles']
tTrailsPossibly['Trail_Elevation_Gain'] = tTrailsPossibly['elevation_gain_feet']
tTrailsPossibly['Trail_Difficulty'] = tTrailsPossibly['difficulty_rating']
tTrailsPossibly['Trail_Route_Type'] = tTrailsPossibly['route_type']
tTrailsPossibly['Trail_Features'] = tTrailsPossibly['features']
tTrailsPossibly['Trail_Activities'] = tTrailsPossibly['activities']

tTrailsPossibly = tTrailsPossibly.drop(columns = ['trail_name'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['national_park'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['state_name'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['popularity'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['length'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['visitor_usage'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['elevation_gain'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['avg_rating'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['num_reviews'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['difficulty_rating'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['route_type'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['activities'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['features'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['elevation_gain_feet'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['length_miles'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['lng'])
tTrailsPossibly = tTrailsPossibly.drop(columns = ['lat'])
                                                  
tTrailsPossibly.head()
# Out:
#                         Trail                   Park_Name   State  Trail_Lat  \
# 0     Harding Ice Field Trail  Kenai Fjords National Park  Alaska   60.18852
# 1  Mount Healy Overlook Trail        Denali National Park  Alaska   63.73049
# 2          Exit Glacier Trail  Kenai Fjords National Park  Alaska   60.18879
# 3        Horseshoe Lake Trail        Denali National Park  Alaska   63.73661
# 4          Triple Lakes Trail        Denali National Park  Alaska   63.73319
#
#    Trail_Lng  Trail_Popularity  Trail_Length  Trail_Elevation_Gain  \
# 0 -149.63156           24.8931      9.702050           3812.000122
# 1 -148.91968           18.0311      4.300909           1666.000053
# 2 -149.63100           17.7821      1.800380            269.000009
# 3 -148.91500           16.2674      2.100444            393.000013
# 4 -148.89682           12.5935     18.503909           3690.000118
#
#    Trail_Difficulty Trail_Route_Type  \
# 0                 5     out and back
# ...

# %%
tTrailsPossibly['Trail_Features'] = tTrailsPossibly['Trail_Features'].str.replace('\[','', regex=True)
tTrailsPossibly['Trail_Features'] = tTrailsPossibly['Trail_Features'].str.replace('\]','', regex=True)
tTrailsPossibly['Trail_Features'] = tTrailsPossibly['Trail_Features'].str.replace('\'','', regex=True)
tTrailsPossibly['Trail_Features'] = tTrailsPossibly['Trail_Features'].str.replace(',',';', regex=True)
tTrailsPossibly['Trail_Activities'] = tTrailsPossibly['Trail_Activities'].str.replace('\[','', regex=True)
tTrailsPossibly['Trail_Activities'] = tTrailsPossibly['Trail_Activities'].str.replace('\]','', regex=True)
tTrailsPossibly['Trail_Activities'] = tTrailsPossibly['Trail_Activities'].str.replace('\'','', regex=True)
tTrailsPossibly['Trail_Activities'] = tTrailsPossibly['Trail_Activities'].str.replace(',',';', regex=True)
tTrailsPossibly['Trail'] = tTrailsPossibly['Trail'].str.replace(',',';', regex=True)
tTrailsPossibly.head(50)
# Out:
#                                                 Trail  \
# 0                             Harding Ice Field Trail
# 1                          Mount Healy Overlook Trail
# 2                                  Exit Glacier Trail
# 3                                Horseshoe Lake Trail
# 4                                  Triple Lakes Trail
# 5                                         Bison Gulch
# 6                                    Rock Creek Trail
# 7                                         Taiga Trail
# 8                              McKinley Station Trail
# 9                          Mount Thorofare Ridge Loop
# 10                                 McKinley Bar Trail
# 11  Tiaga Loop and Horseshoe Lake Trail to Beaver Dam
# 12                               Blueberry Hill Trail
# 13                    Stampede Trail to Sushana River
# 14                    Bartlett Cove Forest Loop Trail
# 15                                   Camp Ridge Trail
# ...

# %%
tTrailsPossibly.to_csv('tTrailsDB.csv', index = False)

# %%
tNatParkPossibly = pd.read_csv('mapTotalsLocations.csv')
tNatParkPossibly
# Out:
#                                           Park_Name  Trail_Total     AvgLat  \
# 0                        Kenai Fjords National Park            2  60.188655
# 1                              Denali National Park           20  63.675311
# 2                         Glacier Bay National Park            5  58.455836
# 3                              Katmai National Park            2  58.558060
# 4                        Grand Canyon National Park           99  36.122555
# 5                             Saguaro National Park           60  32.239590
# 6                    Petrified Forest National Park           15  34.942541
# 7                         Hot Springs National Park           16  34.518655
# 8                            Yosemite National Park          242  37.783247
# 9                             Sequoia National Park           90  36.537113
# 10                        Joshua Tree National Park          108  33.989797
# ...

# %%
tNatParkPossibly.to_csv('tNatParkDB.csv', index = False)
